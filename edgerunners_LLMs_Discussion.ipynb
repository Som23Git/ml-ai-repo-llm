# %% [markdown]
# <a href="https://colab.research.google.com/github/Som23Git/ml-ai-repo-llm/blob/main/edgerunners_LLMs_Discussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's understand how the **Tokens** are split and how it converted took a vector representation of **768** dimensions. We can many hundreds of dimensions, but here I'm just showing with limited dimensions. I'm using GPT2 because it is an opensource model and we don't require secret keys as in GPT-3 or GPT-4.

# %%
from transformers import GPT2Tokenizer, GPT2Model
import torch

# Load pre-trained GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2Model.from_pretrained("gpt2")

# Input text
input_text = "Hello, how are you?"

# Tokenize input text
tokens = tokenizer.tokenize(input_text)
print("Tokens:", tokens)

# Convert tokens to token IDs
input_ids = tokenizer.encode(input_text, return_tensors="pt")
print("Token IDs:", input_ids)

# Generate embeddings for input sequence
with torch.no_grad():
    outputs = model(input_ids)

# Extract embeddings for individual tokens
last_hidden_states = outputs.last_hidden_state
print("Shape of last_hidden_states:", last_hidden_states.shape)

# Get embedding vectors for the first token
embedding_vector_first_token = last_hidden_states[0, 0]
print("Embedding vector for the first token:", embedding_vector_first_token)
print("Dimensionality of the embedding vector:", embedding_vector_first_token.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Tokens: ['Hello', ',', 'Ġhow', 'Ġare', 'Ġyou', '?']
# ...

# %%
Let us check, the token IDs used for vocabulary in GPT2 model as it is an opensource model

# %%
from transformers import GPT2Tokenizer

# Load pre-trained GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Tokenize "hello"
tokens = tokenizer.tokenize("cheat")

# Convert tokens to token IDs
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# Tokens: ['cheat']
# Token IDs: [46799]

# %%
from transformers import GPT2Tokenizer

# Load pre-trained GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Get the vocabulary as a dictionary {token: token_id}
vocabulary = tokenizer.get_vocab()

# Extract tokens and their corresponding token IDs
token_ids_and_tokens = [(token, token_id) for token, token_id in vocabulary.items()]

# Sort the list by token IDs
token_ids_and_tokens.sort(key=lambda x: x[1])

# Print the list of tokens and their corresponding token IDs
for token, token_id in token_ids_and_tokens:
    print(f"Token: {token}, Token ID: {token_id}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Token: ĠKILL, Token ID: 45257
# Token: Marx, Token ID: 45258
# Token: Ġhypocritical, Token ID: 45259
# Token: qus, Token ID: 45260
# Token: ĠNumerous, Token ID: 45261
# Token: ĠGeorgian, Token ID: 45262
# Token: ĠAmbrose, Token ID: 45263
# Token: ĠLoch, Token ID: 45264
# Token: Ġgubernatorial, Token ID: 45265
# Token: ĠXeon, Token ID: 45266
# Token: ĠSupports, Token ID: 45267
# Token: enser, Token ID: 45268
# Token: eely, Token ID: 45269
# Token: ĠAvenger, Token ID: 45270
# Token: 1965, Token ID: 45271
# Token: Army, Token ID: 45272
# Token: Ġjuxtap, Token ID: 45273
# Token: Ġchopping, Token ID: 45274
# Token: ĠSplash, Token ID: 45275
# Token: ĠSustainable, Token ID: 45276
# Token: ĠFinch, Token ID: 45277
# Token: Ġ1861, Token ID: 45278
# Token: ictive, Token ID: 45279
# Token: atmeal, Token ID: 45280
# Token: ĠGohan, Token ID: 45281
# Token: Ġlightsaber, Token ID: 45282
# Token: ĠGPA, Token ID: 45283
# Token: ugu, Token ID: 45284
# ...
